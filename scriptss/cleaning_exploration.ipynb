# %%
import pandas as pd

# %%
df = pd.read_csv("supply_chain_dataset1.csv", keep_default_na=False, na_values = ['NA', '0'])

# %%
def transforming_data():
    df.dropna()
    df[df.duplicated()]
    pd.to_datetime(df['Date'])
    df[df['Unit_Price'] > 0]
    df[df['Unit_Cost'] > 0]

    print(df)
    
transforming_data()
# Out:
#              Date  SKU_ID Warehouse_ID Supplier_ID Region  Units_Sold  \
# 0      2024-01-01   SKU_1         WH_1       SUP_8   West        10.0
# 1      2024-01-02   SKU_1         WH_1       SUP_8   West        17.0
# 2      2024-01-03   SKU_1         WH_1       SUP_8  North        35.0
# 3      2024-01-04   SKU_1         WH_1       SUP_8  South        24.0
# 4      2024-01-05   SKU_1         WH_1       SUP_8   West        21.0
# ...           ...     ...          ...         ...    ...         ...
# 91245  2024-12-26  SKU_50         WH_5      SUP_10  South        17.0
# 91246  2024-12-27  SKU_50         WH_5      SUP_10  South        21.0
# 91247  2024-12-28  SKU_50         WH_5      SUP_10   East        17.0
# 91248  2024-12-29  SKU_50         WH_5      SUP_10  South        24.0
# 91249  2024-12-30  SKU_50         WH_5      SUP_10   West        15.0
#
#        Inventory_Level  Supplier_Lead_Time_Days  Reorder_Point  \
# ...

# %%
def dropping_nanvalues():
    df_nanvalues = df.dropna()

# %%
def duplicates_rows():
    duplicate_rows_df = df[df.duplicated()]

# %%
def conv_data_time():
    converted_date = pd.to_datetime(df['Date'])
    print(converted_date)

conv_data_time()
# Out:
# 0       2024-01-01
# 1       2024-01-02
# 2       2024-01-03
# 3       2024-01-04
# 4       2024-01-05
#            ...
# 91245   2024-12-26
# 91246   2024-12-27
# 91247   2024-12-28
# 91248   2024-12-29
# 91249   2024-12-30
# Name: Date, Length: 91250, dtype: datetime64[ns]

# %%
def bussiness_rules():
    unit_price = df[df['Unit_Price'] > 0]
    unit_cost = df[df['Unit_Cost'] > 0]
